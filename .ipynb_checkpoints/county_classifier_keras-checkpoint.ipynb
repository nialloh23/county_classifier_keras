# %% [markdown]
# ## 1.0 Review Orgininal Dataset

# %%
import os, shutil

# %%
original_mayo_dir = 'D:/Google Images/mayo_original'
original_dublin_dir = 'D:/Google Images/dublin_original'
original_galway_dir = 'D:/Google Images/galway_original'
original_kerry_dir = 'D:/Google Images/kerry_original'

# %%
print('total training Mayo images:', len(os.listdir(original_mayo_dir)))
print('total training Dublin images:', len(os.listdir(original_dublin_dir)))
print('total training Galway images:', len(os.listdir(original_galway_dir)))
print('total training Kerry images:', len(os.listdir(original_kerry_dir)))
# Out:
# total training Mayo images: 449
# total training Dublin images: 523
# total training Galway images: 355
# total training Kerry images: 411

# %%
train_mayo_names = os.listdir(original_mayo_dir)
print(train_mayo_names[:10])

train_dublin_names = os.listdir(original_dublin_dir)
print(train_dublin_names[:10])

train_galway_names = os.listdir(original_galway_dir)
print(train_galway_names[:10])

train_kerry_names = os.listdir(original_kerry_dir)
print(train_kerry_names[:10])
# Out:
# ['mayo (1).png', 'mayo (10).jpeg', 'mayo (10).jpg', 'mayo (10).png', 'mayo (100).jpg', 'mayo (101).jpg', 'mayo (102).jpg', 'mayo (103).jpg', 'mayo (104).jpg', 'mayo (105).jpg']
# ['1.jpg', '100.jpg', '101.jpg', '102.jpg', '103.jpg', '104.jpg', '105.jpeg', '106.jpg', '107.jpg', '108.jpg']
# ['1.jpg', '10.jpg', '100.jpg', '102.jpg', '104.jpg', '105.jpg', '108.jpg', '109.jpg', '11.jpg', '110.jpg']
# ['1.jpeg', '10.png', '101.jpg', '102.jpg', '103.jpg', '104.jpg', '105.jpg', '109.jpg', '11.jpg', '110.jpeg']

# %%
# Now let's take a look at a few pictures to get a better sense of what they look like. First, configure the matplot parameters:

# %%
# %matplotlib inline

import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# Parameters for our graph; we'll output images in a 4x4 configuration
nrows = 4
ncols = 4

# Index for iterating over images
pic_index = 0

# %%
# Set up matplotlib fig, and size it to fit 4x4 pics
fig = plt.gcf()
fig.set_size_inches(ncols * 4, nrows * 4)

pic_index += 4
next_mayo_pix = [os.path.join(original_mayo_dir, fname) 
                for fname in train_mayo_names[pic_index-4:pic_index]]
next_dublin_pix = [os.path.join(original_dublin_dir, fname) 
                for fname in train_dublin_names[pic_index-4:pic_index]]
next_galway_pix = [os.path.join(original_galway_dir, fname) 
                for fname in train_galway_names[pic_index-4:pic_index]]
next_kerry_pix = [os.path.join(original_kerry_dir, fname) 
                for fname in train_kerry_names[pic_index-4:pic_index]]

for i, img_path in enumerate(next_mayo_pix+next_dublin_pix+next_galway_pix+next_kerry_pix):
  # Set up subplot; subplot indices start at 1
  sp = plt.subplot(nrows, ncols, i + 1)
  sp.axis('Off') # Don't show axes (or gridlines)

  img = mpimg.imread(img_path)
  plt.imshow(img)

plt.show()

# %% [markdown]
# # 2.0 Copy Datasets into Train, Val & Test Folders

# %%
train_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/train'
validation_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/validation'
test_dir =  'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/test'

# %%
mayo_train_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/train/mayo'
mayo_validation_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/validation/mayo'
mayo_test_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/test/mayo'

# %%
dublin_train_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/train/dublin'
dublin_validation_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/validation/dublin'
dublin_test_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/test/dublin'

# %%
galway_train_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/train/galway'
galway_validation_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/validation/galway'
galway_test_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/test/galway'

# %%
kerry_train_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/train/kerry'
kerry_validation_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/validation/kerry'
kerry_test_dir = 'D:/Dropbox/08 Year of Learning/04 Deep Learning/fast_ai/county_classifier/images/test/kerry'

# %%
for fname in train_mayo_names[:250]:
    src = os.path.join(original_mayo_dir, fname)
    dst = os.path.join(mayo_train_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_mayo_names[250:300]:
    src = os.path.join(original_mayo_dir, fname)
    dst = os.path.join(mayo_validation_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_mayo_names[300:350]:
    src = os.path.join(original_mayo_dir, fname)
    dst = os.path.join(mayo_test_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_dublin_names[:250]:
    src = os.path.join(original_dublin_dir, fname)
    dst = os.path.join(dublin_train_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_dublin_names[250:300]:
    src = os.path.join(original_dublin_dir, fname)
    dst = os.path.join(dublin_validation_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_dublin_names[300:350]:
    src = os.path.join(original_dublin_dir, fname)
    dst = os.path.join(dublin_test_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_kerry_names[:250]:
    src = os.path.join(original_kerry_dir, fname)
    dst = os.path.join(kerry_train_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_kerry_names[250:300]:
    src = os.path.join(original_kerry_dir, fname)
    dst = os.path.join(kerry_validation_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_kerry_names[300:350]:
    src = os.path.join(original_kerry_dir, fname)
    dst = os.path.join(kerry_test_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_galway_names[:250]:
    src = os.path.join(original_galway_dir, fname)
    dst = os.path.join(galway_train_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_galway_names[250:300]:
    src = os.path.join(original_galway_dir, fname)
    dst = os.path.join(galway_validation_dir, fname)
    shutil.copyfile(src, dst)

# %%
for fname in train_galway_names[300:350]:
    src = os.path.join(original_galway_dir, fname)
    dst = os.path.join(galway_test_dir, fname)
    shutil.copyfile(src, dst)

# %%
#As a sanity check, let's count how many pictures are in each training split (Train Vs Validation)

# %%
print('Total Training Mayo Images:', len(os.listdir(mayo_train_dir)))
# Out:
# Total Training Mayo Images: 250

# %%
print('Total Validation Mayo Images:', len(os.listdir(mayo_validation_dir)))
# Out:
# Total Validation Mayo Images: 50

# %%
print('Total Test Mayo Images:', len(os.listdir(mayo_test_dir)))
# Out:
# Total Test Mayo Images: 50

# %% [markdown]
# ## 2.0 Build Network

# %%
from keras import layers
from keras import models

# %%
model = models.Sequential()

model.add(layers.Conv2D(16, (3,3), activation='relu', input_shape=(300, 300,3)))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(32, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Conv2D(64, (3,3), activation='relu'))
model.add(layers.MaxPooling2D((2,2)))

model.add(layers.Flatten())
model.add(layers.Dense(128, activation='relu'))
model.add(layers.Dense(4, activation='softmax'))

# %%
model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# conv2d_29 (Conv2D)           (None, 298, 298, 16)      448
# _________________________________________________________________
# max_pooling2d_28 (MaxPooling (None, 149, 149, 16)      0
# _________________________________________________________________
# conv2d_30 (Conv2D)           (None, 147, 147, 32)      4640
# _________________________________________________________________
# max_pooling2d_29 (MaxPooling (None, 73, 73, 32)        0
# _________________________________________________________________
# conv2d_31 (Conv2D)           (None, 71, 71, 64)        18496
# _________________________________________________________________
# max_pooling2d_30 (MaxPooling (None, 35, 35, 64)        0
# _________________________________________________________________
# flatten_8 (Flatten)          (None, 78400)             0
# ...

# %% [markdown]
# # 3.0 Compile & Run Model

# %%
from keras import optimizers

model.compile(
    loss='categorical_crossentropy',
    optimizer= optimizers.RMSprop(lr=0.001),
    metrics =['acc'])

# %% [markdown]
# # 4.0 Data Preprocessing

# %%
from keras.preprocessing.image import ImageDataGenerator

#All images will be rescaled by 1./255
train_datagen = ImageDataGenerator(rescale=1./255)
validation_datagen = ImageDataGenerator(rescale=1./255)

# %%
#Flow training images in batches of 50 using train_datagen generator
train_generator = train_datagen.flow_from_directory(
    train_dir,
    target_size=(300, 300),
    batch_size = 10,
    class_mode='categorical',
    color_mode='rgb',
)
# Out:
# Found 1000 images belonging to 4 classes.

# %%
#Flow validation images in batches of 10 using validation_datagen generator

validation_generator = validation_datagen.flow_from_directory(
    validation_dir,
    target_size=(300, 300),
    batch_size = 10,
    class_mode='categorical',
    color_mode='rgb',
)
# Out:
# Found 200 images belonging to 4 classes.

# %% [markdown]
# # 5.0 Fitting the model using batch generator

# %%
history = model.fit_generator(
    train_generator,
    steps_per_epoch=25,
    epochs=15,
    validation_data=validation_generator,
    validation_steps=5,
    verbose=2
)
# Out:
# C:\Users\User\Anaconda3\envs\py36\lib\site-packages\theano\tensor\nnet\conv.py:98: UserWarning: theano.tensor.nnet.conv.conv2d is deprecated. Use theano.tensor.nnet.conv2d instead.
#   warnings.warn("theano.tensor.nnet.conv.conv2d is deprecated."
# Epoch 1/15
# C:\Users\User\Anaconda3\envs\py36\lib\site-packages\theano\tensor\signal\pool.py:574: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   yk[[region_slices[i][r[i]] for i in xrange(nd)]])
# ...

# %%
model.save('county_classifier_1.h5')

# %% [markdown]
# # 6.0 Plot Results

# %%
import matplotlib.pyplot as plt

acc = history.history['acc']
val_acc = history.history['val_acc']
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs = range(1, len(acc) + 1)

plt.plot(epochs, acc, 'bo', label='Training acc')
plt.plot(epochs, val_acc, 'b', label='Validation acc')
plt.title('Training & Validation Accuracy')
plt.legend()
plt.figure()

plt.plot(epochs, loss, 'bo', label='Training Loss')
plt.plot(epochs, val_loss, 'b', label='Validation Loss')
plt.title('Training & Validation Loss')
plt.legend()
plt.show()

# %% [markdown]
# # 7.0 Running the Model

# %% [markdown]
# # 8.0 Visualizing Intermediate Representations

# %%
import numpy as np
import random
from keras.preprocessing.image import img_to_array, load_img

# Let's define a new Model that will take an image as input, and will output
# intermediate representations for all layers in the previous model after
# the first.
successive_outputs = [layer.output for layer in model.layers[1:]]
#visualization_model = Model(img_input, successive_outputs)
visualization_model = keras.models.Model(inputs = model.input, outputs = successive_outputs)
# Let's prepare a random input image from the training set.
mayo_img_files = [os.path.join(original_mayo_directory, f) for f in train_mayo_names]
dublin_img_files = [os.path.join(original_dublin_directory, f) for f in train_dublin_names]



img_path = random.choice(mayo_img_files + dublin_img_files)

img = load_img(img_path, target_size=(300, 300))  # this is a PIL image
x = img_to_array(img)  # Numpy array with shape (150, 150, 3)
x = x.reshape((1,) + x.shape)  # Numpy array with shape (1, 150, 150, 3)

# Rescale by 1/255
x /= 255

# Let's run our image through our network, thus obtaining all
# intermediate representations for this image.
successive_feature_maps = visualization_model.predict(x)

# These are the names of the layers, so can have them as part of our plot
layer_names = [layer.name for layer in model.layers]

# Now let's display our representations
for layer_name, feature_map in zip(layer_names, successive_feature_maps):
  if len(feature_map.shape) == 4:
    # Just do this for the conv / maxpool layers, not the fully-connected layers
    n_features = feature_map.shape[-1]  # number of features in feature map
    # The feature map has shape (1, size, size, n_features)
    size = feature_map.shape[1]
    # We will tile our images in this matrix
    display_grid = np.zeros((size, size * n_features))
    for i in range(n_features):
      # Postprocess the feature to make it visually palatable
      x = feature_map[0, :, :, i]
      x -= x.mean()
      x /= x.std()
      x *= 64
      x += 128
      x = np.clip(x, 0, 255).astype('uint8')
      # We'll tile each filter into this big horizontal grid
      display_grid[:, i * size : (i + 1) * size] = x
    # Display the grid
    scale = 20. / n_features
    plt.figure(figsize=(scale * n_features, scale))
    plt.title(layer_name)
    plt.grid(False)
    plt.imshow(display_grid, aspect='auto', cmap='viridis')
